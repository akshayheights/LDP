# %%
dbutils.widgets.text("dlt_pipeline_id", "")
dbutils.widgets.text("dlt_pipeline_run_id", "")
dbutils.widgets.text("dlt_pipeline_result_state", "")

print("✅ Postprocess Notebook Started")
print("DLT Pipeline ID:", dbutils.widgets.get("dlt_pipeline_id"))
print("DLT Run ID:", dbutils.widgets.get("dlt_pipeline_run_id"))
print("DLT Result State:", dbutils.widgets.get("dlt_pipeline_result_state"))

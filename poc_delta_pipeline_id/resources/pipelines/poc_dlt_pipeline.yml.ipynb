# %%
resources:
  pipelines:
    poc_dlt_pipeline:
      name: poc_dlt_pipeline
      catalog: main
      schema: poc_schema
      serverless: true
      photon: true

      libraries:
        - notebook:
            path: /Workspace/Users/akshayheights@gmail.com/LDP/poc_delta_pipeline_id/resources/notebooks/dlt_notebook

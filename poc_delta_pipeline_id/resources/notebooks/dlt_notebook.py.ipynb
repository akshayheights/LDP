# %%
import dlt
from pyspark.sql.functions import current_timestamp

@dlt.table(name="poc_table", comment="A simple DLT test table")
def sample_trips_bunle_poc():
    return spark.read.table("samples.nyctaxi.trips")
